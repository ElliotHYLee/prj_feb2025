# %% [markdown]
# # count all the words

# %%
import numpy as np
import string

file = open("shakespeare.txt", "r")
tokens = file.read().split()
file.close()

print('done reading')

print(len(tokens))

print(tokens[:100])

dict_count = {}

for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()
    # remove punctuation
    for punct in string.punctuation:
        tokens[i] = tokens[i].replace(punct, '')
    if tokens[i] in dict_count:
        dict_count[tokens[i]] += 1
    else:
        dict_count[tokens[i]] = 1

print(dict_count)

# sort the dictionary by value
sorted_dict = sorted(dict_count.items(), key=lambda x: x[1], reverse=True)
print(sorted_dict[:10])
# Out:
# done reading
# 202651
# ['First', 'Citizen:', 'Before', 'we', 'proceed', 'any', 'further,', 'hear', 'me', 'speak.', 'All:', 'Speak,', 'speak.', 'First', 'Citizen:', 'You', 'are', 'all', 'resolved', 'rather', 'to', 'die', 'than', 'to', 'famish?', 'All:', 'Resolved.', 'resolved.', 'First', 'Citizen:', 'First,', 'you', 'know', 'Caius', 'Marcius', 'is', 'chief', 'enemy', 'to', 'the', 'people.', 'All:', 'We', "know't,", 'we', "know't.", 'First', 'Citizen:', 'Let', 'us', 'kill', 'him,', 'and', "we'll", 'have', 'corn', 'at', 'our', 'own', 'price.', "Is't", 'a', 'verdict?', 'All:', 'No', 'more', 'talking', "on't;", 'let', 'it', 'be', 'done:', 'away,', 'away!', 'Second', 'Citizen:', 'One', 'word,', 'good', 'citizens.', 'First', 'Citizen:', 'We', 'are', 'accounted', 'poor', 'citizens,', 'the', 'patricians', 'good.', 'What', 'authority', 'surfeits', 'on', 'would', 'relieve', 'us:', 'if', 'they', 'would']
# {'first': 361, 'citizen': 100, 'before': 193, 'we': 865, 'proceed': 21, 'any': 189, 'further': 36, 'hear': 230, 'me': 1764, 'speak': 292, 'all': 890, 'you': 3142, 'are': 784, 'resolved': 15, 'rather': 77, 'to': 4766, 'die': 138, 'than': 480, 'famish': 4, 'know': 350, 'caius': 17, 'marcius': 122, 'is': 2078, 'chief': 7, 'enemy': 42, 'the': 6283, 'people': 88, 'knowt': 6, 'let': 437, 'us': 399, 'kill': 49, 'him': 1206, 'and': 5680, 'well': 563, 'have': 1448, 'corn': 14, 'at': 561, 'our': 786, 'own': 170, 'price': 7, 'ist': 38, 'a': 2987, 'verdict': 2, 'no': 903, 'more': 578, 'talking': 5, 'ont': 24, 'it': 1759, 'be': 1701, 'done': 169, 'away': 186, 'second': 168, 'one': 423, 'word': 125, 'good': 669, 'citizens': 42, 'accounted': 2, 'poor': 156, 'patricians': 10, 'what': 1127, 'authority': 15, 'surfeits': 2, 'on': 667, 'would': 532, 'relieve': 3, 'if': 802, 'they': 527, 'yield': 43, 'but': 1502, 'superfluity': 2, 'while': 80, 'were': 412, 'wholesome': 9, 'might': 105, 'guess': 20, 'relieved': 1, 'humanely': 1, 'think': 218, 'too': 309, 'dear': 101, 'leanness': 3, 'that': 2569, 'afflicts': 1, 'object': 7, 'of': 3757, 'misery': 12, 'as': 1410, 'an': 363, 'inventory': 1, 'particularise': 1, 'their': 476, 'abundance': 3, 'sufferance': 5, 'gain': 14, 'them': 473, 'revenge': 39, 'this': 1504, 'with': 1809, 'pikes': 3, 'ere': 110, 'become': 37, 'rakes': 1, 'for': 1893, '